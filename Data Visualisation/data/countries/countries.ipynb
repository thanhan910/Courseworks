# %% [markdown]
# # Countries statistics and energy use statistics
#
# This dataset contains the statistics and energy use of countries around the world, and each countries region according to multiple definitons. The following notebook will outline the entire creation of the dataset, going from the creation of the Entities dataset, to the creation of the info dataset, to the final creation of the dataset.

# %% [markdown]
# ## Entities Dataset
#
# ### Introduction
#
# This dataset contains a comprehensive list of all countries, entities, each entity's ISO code and group classification. It serves as a conversion of ISO codes between country codes used in [Our World in Data (OWID)](https://ourworldindata.org/)'s datasets, country codes used in [World Bank (WB)'s World Development Indicators (WDI)](https://data.worldbank.org/), and country codes used in the [Internation Monetary Fund (IMF)'s World Economic Outlook (WEO)](https://www.imf.org/en/Publications/WEO/weo-database/2022/April).
#
# The dataset is available in the [entities.csv](/entities.csv) file. We used the [process.py](/process.py) script to collect and process the data.
#
# #### Available entities
#
# The entities listed in this dataset consists of entities available in OWID's datasets, WB's WDI, and WEO. For OWID datasets, we select countries from OWID's [Standard entity names](https://github.com/owid/energy-data/tree/master/scripts/input/shared), [World map region definitions](https://ourworldindata.org/world-region-map-definitions), [Energy Dataset](https://github.com/owid/energy-data), and [CO2 Dataset](https://github.com/owid/co2-data)
#
# #### Data collection
#
# ##### Our World in Data
#
# - For OWID's [Standard entity names](https://github.com/owid/energy-data/tree/master/scripts/input/shared), we sourced the data from https://raw.githubusercontent.com/owid/energy-data/master/scripts/input/shared/iso_codes.csv.
#
# - For OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions), we went to the [website](https://ourworldindata.org/world-region-map-definitions) and manually downloaded the data available on it.
#
# - For OWID's [Energy Data](https://github.com/owid/energy-data), we sourced the data from https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv.
#
# - For OWD's [CO2 Data](https://github.com/owid/co2-data), we sourced the data from https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv.
#
# ##### World Bank's World Development Indicators
#
# We used the `get_countries` method from the `world_bank_data` [Python package](https://github.com/mwouts/world_bank_data) to get the list of countries available in WDI. The package is availabe here.
#
# ```python
# import world_bank_data as wb
#
# df_wb = wb.get_countries()
# ```
#
# ##### IMF's World Economic Outlook
#
# We used the `weo` [Python client](https://github.com/epogrebnyak/weo-reader) to get the list of countries available in WEO.
#
# ```python
# import weo
#
# path, url = weo.download(2022, 1)
#
# df_weo = weo.WEO(path).countries()
# ```
#
# #### Variables
#
# The variables code, definition, and sources are available in our [variables.csv](/variables.csv) file. Below are the details of the variables, i.e., attributes:
#
# | Column          | Description                                                                                                 | Source                              |
# | --------------- | ----------------------------------------------------------------------------------------------------------- | ----------------------------------- |
# | `Code`            | Country Code of all entities in the dataset. We prioritize OWID codes, then WB codes, and finally WEO codes | OWID, WB, WEO                       |
# | `Entity`          | The Entity name. We prioritize the shortest, most English Alphabetic name                                   | OWID, WB, WEO                       |
# | `OWID`            | Entity's OWID ISO code                                                                                      | OWID                                |
# | `OWID_Name`       | Entity's Name according to OWID. The names come from different datasets of OWID                             | OWID                                |
# | `OWID_Continent`  | Entity's Continent. Sourced from Our World in Data                                                          | OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions) |
# | `OWID_WHO_Region` | Entity's WHO region. Sourced from Our World in Data                                                         | OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions) |
# | `OWID_WB_Region`  | Entity's region according to the World Bank.  Sourced from Our World in Data                                | OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions) |
# | `OWID_UN_Region`  | Entity's region according to the United Nations. Sourced from Our World in Data.                            | OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions) |
# | `WB`              | Entity's World Bank ISO3 code                                                                               | WB                                  |
# | `WB_ISO2`         | Entity's World Bank ISO2 code                                                                               | WB                                  |
# | `WB_Name`         | Entity's name according to the World Bank                                                                   | WB                                  |
# | `WB_region`       | Entity's World Bank region                                                                                  | WB                                  |
# | `WB_adminregion`  | Entity's World Bank administrative region                                                                   | WB                                  |
# | `WB_incomeLevel`  | Entity's income level according to the World Bank                                                           | WB                                  |
# | `WB_lendingType`  | Entity's World Bank lending type                                                                            | WB                                  |
# | `WB_capitalCity`  | Entity's capital city according to the World Bank                                                           | WB                                  |
# | `WB_longitude`    | Entity's capital city according to the World Bank                                                           | WB                                  |
# | `WB_latitude`     | Entity's capital city according to the World Bank                                                           | WB                                  |
# | `WEO`             | Entity's WEO ISO code                                                                                       | WEO                                 |
# | `WEO_Country`     | Entity's name according to the World Economic Outlook                                                       | WEO                                 |

# %% [markdown]
# ### Chapter 1: Our World in Data
#
# First we want to create a dataset of all countries, their ISO codes and regions from Our World in Data. Our main sources would be the OWID's [World map region definitions](https://ourworldindata.org/world-region-map-definitions) page and OWID's [standard entity names](https://github.com/owid/energy-data/tree/master/scripts/input/shared). ([source](https://raw.githubusercontent.com/owid/energy-data/master/scripts/input/shared/iso_codes.csv)).
#
# However, these sources did not list all available OWID's entities, so we will also interpolate our dataset with entities listed in OWID's [Energy Data](https://github.com/owid/energy-data) ([source](https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv)), and [CO2 Data](https://github.com/owid/co2-data) ([source](https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv))

# %% [markdown]
# #### World map region definitions
#
# First, we manually download the datasets from https://ourworldindata.org/world-region-map-definitions and stored them in the "owid" directory.
#
# Then, we read those downloaded csv file, store each csv table in a DataFrame, and merge the DataFrames together using the Code attribute.

# %%
# import the needed packages
import pandas as pd
import os

# %%
# read the files

entities_directory = "entities/"

datafiles = []

for dirpath, _, filenames in os.walk(entities_directory + "owid"):
    for f in filenames:
        datafiles.append(os.path.join(dirpath, f))

datafiles
# Out:
# ['entities/owid\\continents-according-to-our-world-in-data.csv',
#  'entities/owid\\who-regions.csv',
#  'entities/owid\\world-regions-according-to-the-world-bank.csv',
#  'entities/owid\\world-regions-sdg-united-nations.csv']

# %%
# load each file into a DataFrame

dfs = []

for f in datafiles:
    # drop the Year column since we don't need it
    df = pd.read_csv(f).drop('Year', axis=1)
    dfs.append(df)

dfs
# Out:
# [                    Entity      Code Continent
#  0                 Abkhazia  OWID_ABK      Asia
#  1              Afghanistan       AFG      Asia
#  2    Akrotiri and Dhekelia  OWID_AKD      Asia
#  3                  Albania       ALB    Europe
#  4                  Algeria       DZA    Africa
#  ..                     ...       ...       ...
#  280             Yugoslavia  OWID_YGS    Europe
#  281                 Zambia       ZMB    Africa
#  282               Zanzibar  OWID_ZAN    Africa
#  283               Zimbabwe       ZWE    Africa
#  284          Åland Islands       ALA    Europe
#
#  [285 rows x 3 columns],
#            Entity Code             WHO region
#  0    Afghanistan  AFG  Eastern Mediterranean
#  1        Albania  ALB                 Europe
#  2        Algeria  DZA                 Africa
#  3        Andorra  AND                 Europe
#  4         Angola  AGO                 Africa
#  ..           ...  ...                    ...
#  189    Venezuela  VEN               Americas
#  190      Vietnam  VNM        Western Pacific
#  191        Yemen  YEM  Eastern Mediterranean
#  192       Zambia  ZMB                 Africa
#  193     Zimbabwe  ZWE                 Africa
#
#  [194 rows x 3 columns],
#               Entity Code World Region according to the World Bank
#  0       Afghanistan  AFG                               South Asia
#  1           Albania  ALB                  Europe and Central Asia
#  2           Algeria  DZA             Middle East and North Africa
#  3    American Samoa  ASM                    East Asia and Pacific
#  4           Andorra  AND                  Europe and Central Asia
#  ..              ...  ...                                      ...
#  212       Venezuela  VEN              Latin America and Caribbean
#  213         Vietnam  VNM                    East Asia and Pacific
#  214           Yemen  YEM             Middle East and North Africa
#  215          Zambia  ZMB                       Sub-Saharan Africa
#  216        Zimbabwe  ZWE                       Sub-Saharan Africa
#
#  [217 rows x 3 columns],
#                  Entity Code world-regions-according-to-the-united-nations
#  0          Afghanistan  AFG                     Central and Southern Asia
#  1        Aland Islands  NaN                   Europe and Northern America
#  2              Albania  ALB                   Europe and Northern America
#  3              Algeria  DZA              Northern Africa and Western Asia
#  4       American Samoa  ASM                                       Oceania
#  ..                 ...  ...                                           ...
#  233  Wallis and Futuna  WLF                                       Oceania
#  234     Western Sahara  ESH              Northern Africa and Western Asia
#  235              Yemen  YEM              Northern Africa and Western Asia
#  236             Zambia  ZMB                            Sub-Saharan Africa
#  237           Zimbabwe  ZWE                            Sub-Saharan Africa
#
#  [238 rows x 3 columns]]

# %%
# merge all dataframes based on Entity and Code

df_merged = dfs[0]

for df in dfs[1:]:
    df_merged = pd.merge(df_merged, df, on=["Entity", "Code"], how="outer")

df_merged
# Out:
#                       Entity      Code Continent             WHO region  \
# 0                   Abkhazia  OWID_ABK      Asia                    NaN
# 1                Afghanistan       AFG      Asia  Eastern Mediterranean
# 2      Akrotiri and Dhekelia  OWID_AKD      Asia                    NaN
# 3                    Albania       ALB    Europe                 Europe
# 4                    Algeria       DZA    Africa                 Africa
# ..                       ...       ...       ...                    ...
# 283                 Zimbabwe       ZWE    Africa                 Africa
# 284            Åland Islands       ALA    Europe                    NaN
# 285               Micronesia       NaN       NaN                    NaN
# 286            Aland Islands       NaN       NaN                    NaN
# 287  Cocos (Keeling) Islands       NaN       NaN                    NaN
#
#     World Region according to the World Bank  \
# 0                                        NaN
# 1                                 South Asia
# 2                                        NaN
# 3                    Europe and Central Asia
# 4               Middle East and North Africa
# ..                                       ...
# 283                       Sub-Saharan Africa
# 284                                      NaN
# 285                    East Asia and Pacific
# 286                                      NaN
# 287                                      NaN
#
#     world-regions-according-to-the-united-nations
# 0                                             NaN
# 1                       Central and Southern Asia
# 2                                             NaN
# 3                     Europe and Northern America
# 4                Northern Africa and Western Asia
# ..                                            ...
# 283                            Sub-Saharan Africa
# 284                                           NaN
# 285                                       Oceania
# 286                   Europe and Northern America
# 287                                       Oceania
#
# [288 rows x 6 columns]

# %% [markdown]
# #### OWID Energy Data

# %%
# read the energy data file
df = pd.read_csv("https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv")
df

# retrieve all iso codes and countries available in the datafile
df = df[["iso_code", "country"]].drop_duplicates()
df
# set index as iso code and country
df_owid_energy_data = df.set_index(["iso_code", "country"])
df_owid_energy_data
# Out:
# Empty DataFrame
# Columns: []
# Index: [(AFG, Afghanistan), (OWID_AFR, Africa), (ALB, Albania), (DZA, Algeria), (ASM, American Samoa), (AGO, Angola), (nan, Antarctica), (ATG, Antigua and Barbuda), (ARG, Argentina), (ARM, Armenia), (ABW, Aruba), (nan, Asia Pacific), (AUS, Australia), (AUT, Austria), (AZE, Azerbaijan), (BHS, Bahamas), (BHR, Bahrain), (BGD, Bangladesh), (BRB, Barbados), (BLR, Belarus), (BEL, Belgium), (BLZ, Belize), (BEN, Benin), (BMU, Bermuda), (BTN, Bhutan), (BOL, Bolivia), (BIH, Bosnia and Herzegovina), (BWA, Botswana), (BRA, Brazil), (VGB, British Virgin Islands), (BRN, Brunei), (BGR, Bulgaria), (BFA, Burkina Faso), (BDI, Burundi), (nan, CIS), (KHM, Cambodia), (CMR, Cameroon), (CAN, Canada), (CPV, Cape Verde), (CYM, Cayman Islands), (CAF, Central African Republic), (TCD, Chad), (CHL, Chile), (CHN, China), (COL, Colombia), (COM, Comoros), (COG, Congo), (COK, Cook Islands), (CRI, Costa Rica), (CIV, Cote d'Ivoire), (HRV, Croatia), (CUB, Cuba), (CYP, Cyprus), (CZE, Czechia), (nan, Czechoslovakia), (COD, Democratic Republic of Congo), (DNK, Denmark), (DJI, Djibouti), (DMA, Dominica), (DOM, Dominican Republic), (nan, East Germany), (nan, Eastern Africa), (ECU, Ecuador), (EGY, Egypt), (SLV, El Salvador), (GNQ, Equatorial Guinea), (ERI, Eritrea), (EST, Estonia), (SWZ, Eswatini), (ETH, Ethiopia), (OWID_EUR, Europe), (OWID_EU27, European Union (27)), (FRO, Faeroe Islands), (FLK, Falkland Islands), (FJI, Fiji), (FIN, Finland), (FRA, France), (GUF, French Guiana), (PYF, French Polynesia), (GAB, Gabon), (GMB, Gambia), (GEO, Georgia), (DEU, Germany), (GHA, Ghana), (GRC, Greece), (GRL, Greenland), (nan, Greenland), (GRD, Grenada), (GLP, Guadeloupe), (GUM, Guam), (GTM, Guatemala), (GIN, Guinea), (GNB, Guinea-Bissau), (GUY, Guyana), (HTI, Haiti), (nan, Hawaiian Trade Zone), (HND, Honduras), (HKG, Hong Kong), (HUN, Hungary), (ISL, Iceland), ...]
#
# [244 rows x 0 columns]

# %% [markdown]
# #### OWID CO2 Data

# %%
# read the OWID CO2 data
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")
df


# retrieve all iso codes and countries available in the datafile
df = df[["iso_code", "country"]].drop_duplicates()
df

# set index as iso code and country
df_owid_co2_data = df.set_index(["iso_code", "country"])
df_owid_co2_data


# merge two country lists from energy data and co2 data
df_owid_data = pd.merge(df_owid_energy_data, df_owid_co2_data, how="outer", left_index=True, right_index=True)
df_owid_data
# Out:
# Empty DataFrame
# Columns: []
# Index: [(ABW, Aruba), (AFG, Afghanistan), (AGO, Angola), (AIA, Anguilla), (ALB, Albania), (AND, Andorra), (ANT, Netherlands Antilles), (ARE, United Arab Emirates), (ARG, Argentina), (ARM, Armenia), (ASM, American Samoa), (ATG, Antigua and Barbuda), (AUS, Australia), (AUT, Austria), (AZE, Azerbaijan), (BDI, Burundi), (BEL, Belgium), (BEN, Benin), (BES, Bonaire Sint Eustatius and Saba), (BFA, Burkina Faso), (BGD, Bangladesh), (BGR, Bulgaria), (BHR, Bahrain), (BHS, Bahamas), (BIH, Bosnia and Herzegovina), (BLR, Belarus), (BLZ, Belize), (BMU, Bermuda), (BOL, Bolivia), (BRA, Brazil), (BRB, Barbados), (BRN, Brunei), (BTN, Bhutan), (BWA, Botswana), (CAF, Central African Republic), (CAN, Canada), (CHE, Switzerland), (CHL, Chile), (CHN, China), (CIV, Cote d'Ivoire), (CMR, Cameroon), (COD, Democratic Republic of Congo), (COG, Congo), (COK, Cook Islands), (COL, Colombia), (COM, Comoros), (CPV, Cape Verde), (CRI, Costa Rica), (CUB, Cuba), (CUW, Curacao), (CXR, Christmas Island), (CYM, Cayman Islands), (CYP, Cyprus), (CZE, Czechia), (DEU, Germany), (DJI, Djibouti), (DMA, Dominica), (DNK, Denmark), (DOM, Dominican Republic), (DZA, Algeria), (ECU, Ecuador), (EGY, Egypt), (ERI, Eritrea), (ESH, Western Sahara), (ESP, Spain), (EST, Estonia), (ETH, Ethiopia), (FIN, Finland), (FJI, Fiji), (FLK, Falkland Islands), (FRA, France), (FRO, Faeroe Islands), (FSM, Micronesia (country)), (GAB, Gabon), (GBR, United Kingdom), (GEO, Georgia), (GHA, Ghana), (GIN, Guinea), (GLP, Guadeloupe), (GMB, Gambia), (GNB, Guinea-Bissau), (GNQ, Equatorial Guinea), (GRC, Greece), (GRD, Grenada), (GRL, Greenland), (GTM, Guatemala), (GUF, French Guiana), (GUM, Guam), (GUY, Guyana), (HKG, Hong Kong), (HND, Honduras), (HRV, Croatia), (HTI, Haiti), (HUN, Hungary), (IDN, Indonesia), (IND, India), (IRL, Ireland), (IRN, Iran), (IRQ, Iraq), (ISL, Iceland), ...]
#
# [283 rows x 0 columns]

# %% [markdown]
# #### Standard Entity Names

# %%
# read the standard entity names file
df = pd.read_csv("https://raw.githubusercontent.com/owid/energy-data/master/scripts/input/shared/iso_codes.csv")
df


# drop duplicates
df.drop_duplicates(subset="iso_code")
df

# rename column
df.rename(columns={'Country': 'country'}, inplace=True)
df


# set index as iso code and country
df_owid_country = df.set_index(["iso_code", "country"])
df_owid_country

# merge the standard country dataframe with the owid energy+co2 dataframe
df_owid = pd.merge(df_owid_data, df_owid_country, how="outer",
                    left_index=True, right_index=True)
df_owid

# reset index
df_owid = df_owid.reset_index()
df_owid

# rename columns to merge with df_merge
df_owid.rename(columns={'country': 'Entity', 'iso_code': 'Code'}, inplace=True)
df_owid

# merge with df_merged
df = pd.merge(df_owid, df_merged, how="outer", on=["Entity", "Code"])
df
# Out:
#          Code                   Entity      Continent             WHO region  \
# 0         ABW                    Aruba  North America                    NaN
# 1         AFG              Afghanistan           Asia  Eastern Mediterranean
# 2         AGO                   Angola         Africa                 Africa
# 3         AIA                 Anguilla  North America                    NaN
# 4         ALA            Åland Islands         Europe                    NaN
# ..        ...                      ...            ...                    ...
# 356  OWID_YGS               Yugoslavia         Europe                    NaN
# 357  OWID_ZAN                 Zanzibar         Africa                    NaN
# 358       NaN               Micronesia            NaN                    NaN
# 359       NaN            Aland Islands            NaN                    NaN
# 360       NaN  Cocos (Keeling) Islands            NaN                    NaN
#
#     World Region according to the World Bank  \
# 0                Latin America and Caribbean
# 1                                 South Asia
# 2                         Sub-Saharan Africa
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 356                                      NaN
# 357                                      NaN
# 358                    East Asia and Pacific
# 359                                      NaN
# 360                                      NaN
#
#     world-regions-according-to-the-united-nations
# 0                     Latin America and Caribbean
# 1                       Central and Southern Asia
# 2                              Sub-Saharan Africa
# 3                     Latin America and Caribbean
# 4                                             NaN
# ..                                            ...
# 356                                           NaN
# 357                                           NaN
# 358                                       Oceania
# 359                   Europe and Northern America
# 360                                       Oceania
#
# [361 rows x 6 columns]

# %% [markdown]
# #### Process with Excel

# %%
# output to csv file to process with Excel
df.to_csv(entities_directory + "output/owid.csv")
df
# Out:
#          Code                   Entity      Continent             WHO region  \
# 0         ABW                    Aruba  North America                    NaN
# 1         AFG              Afghanistan           Asia  Eastern Mediterranean
# 2         AGO                   Angola         Africa                 Africa
# 3         AIA                 Anguilla  North America                    NaN
# 4         ALA            Åland Islands         Europe                    NaN
# ..        ...                      ...            ...                    ...
# 356  OWID_YGS               Yugoslavia         Europe                    NaN
# 357  OWID_ZAN                 Zanzibar         Africa                    NaN
# 358       NaN               Micronesia            NaN                    NaN
# 359       NaN            Aland Islands            NaN                    NaN
# 360       NaN  Cocos (Keeling) Islands            NaN                    NaN
#
#     World Region according to the World Bank  \
# 0                Latin America and Caribbean
# 1                                 South Asia
# 2                         Sub-Saharan Africa
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 356                                      NaN
# 357                                      NaN
# 358                    East Asia and Pacific
# 359                                      NaN
# 360                                      NaN
#
#     world-regions-according-to-the-united-nations
# 0                     Latin America and Caribbean
# 1                       Central and Southern Asia
# 2                              Sub-Saharan Africa
# 3                     Latin America and Caribbean
# 4                                             NaN
# ..                                            ...
# 356                                           NaN
# 357                                           NaN
# 358                                       Oceania
# 359                   Europe and Northern America
# 360                                       Oceania
#
# [361 rows x 6 columns]

# %% [markdown]
# In the Excel file, we selected any countries without a Code and check if the country is duplicated in the file or not.
# We also added all empty and NaN ISO code values with a specific id, in order not to merge NaN id values with df_wb in the future.
# The cleaning process with Excel was done in the [custom/ProcessBook.xlsx](/custom/ProcessBook.xlsx) file
# After processing with Excel, we reload the file back to continue.

# %%
# read the processed data from Excel
df_owid = pd.read_csv(entities_directory + "custom/owid.csv")
df_owid
# Out:
#           Code                         Entity      Continent  \
# 0          ABW                          Aruba  North America
# 1          AFG                    Afghanistan           Asia
# 2          AGO                         Angola         Africa
# 3          AIA                       Anguilla  North America
# 4          ALA                  Aland Islands         Europe
# ..         ...                            ...            ...
# 318  _empty_30           U.S. Pacific Islands            NaN
# 319  _empty_31               U.S. Territories            NaN
# 320  _empty_32  Upper-middle-income countries            NaN
# 321  _empty_33                    Wake Island            NaN
# 322  _empty_34                 Western Africa            NaN
#
#                 WHO region World Region according to the World Bank  \
# 0                      NaN              Latin America and Caribbean
# 1    Eastern Mediterranean                               South Asia
# 2                   Africa                       Sub-Saharan Africa
# 3                      NaN                                      NaN
# 4                      NaN                                      NaN
# ..                     ...                                      ...
# 318                    NaN                                      NaN
# 319                    NaN                                      NaN
# 320                    NaN                                      NaN
# 321                    NaN                                      NaN
# 322                    NaN                                      NaN
#
#     world-regions-according-to-the-united-nations
# 0                     Latin America and Caribbean
# 1                       Central and Southern Asia
# 2                              Sub-Saharan Africa
# 3                     Latin America and Caribbean
# 4                     Europe and Northern America
# ..                                            ...
# 318                                           NaN
# 319                                           NaN
# 320                                           NaN
# 321                                           NaN
# 322                                           NaN
#
# [323 rows x 6 columns]

# %% [markdown]
# ### Chapter 2: World Bank

# %%
# import python package
import world_bank_data as wb

# get countries available in World Bank database
df_wb = wb.get_countries()
df_wb
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFE       ZH                        Africa Eastern and Southern
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AFW       ZI                         Africa Western and Central
# ..       ...                                                ...
# XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# YEM       YE                                        Yemen, Rep.
# ZAF       ZA                                       South Africa
# ZMB       ZM                                             Zambia
# ZWE       ZW                                           Zimbabwe
#
#                          region  \
# id
# ABW  Latin America & Caribbean
# AFE                  Aggregates
# AFG                  South Asia
# AFR                  Aggregates
# AFW                  Aggregates
# ..                          ...
# XZN                  Aggregates
# YEM  Middle East & North Africa
# ZAF         Sub-Saharan Africa
# ZMB         Sub-Saharan Africa
# ZWE         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# id
# ABW                                                             High income
# AFE                                                              Aggregates
# AFG                                         South Asia           Low income
# AFR                                                              Aggregates
# AFW                                                              Aggregates
# ..                                                 ...                  ...
# XZN                                                              Aggregates
# YEM  Middle East & North Africa (excluding high inc...           Low income
# ZAF         Sub-Saharan Africa (excluding high income)  Upper middle income
# ZMB         Sub-Saharan Africa (excluding high income)  Lower middle income
# ZWE         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# id
# ABW  Not classified  Oranjestad   -70.0167   12.5167
# AFE      Aggregates                    NaN       NaN
# AFG             IDA       Kabul    69.1761   34.5228
# AFR      Aggregates                    NaN       NaN
# AFW      Aggregates                    NaN       NaN
# ..              ...         ...        ...       ...
# XZN      Aggregates                    NaN       NaN
# YEM             IDA      Sana'a    44.2075   15.3520
# ZAF            IBRD    Pretoria    28.1871  -25.7460
# ZMB             IDA      Lusaka    28.2937  -15.3982
# ZWE           Blend      Harare    31.0672  -17.8312
#
# [299 rows x 9 columns]

# %% [markdown]
# #### Merge World Bank data with OWID datas

# %%
# save the World Bank's ISO code to another column before merging with df_owid
df_wb["WB"] = df_wb.index
df_wb

# Save the Code in the OWID column before merging with df_wb
df_owid["OWID"] = df_owid["Code"]
df_owid

# merge df_owid with df_wb and write the table to a csv file to process with Excel
df = pd.merge(df_owid, df_wb, how="outer", left_on="Code", right_index=True)
df.to_csv(entities_directory + "output/owidwb.csv")
df
# after this, I have opened the file in excel and clean the data manually
# Out:
#     Code         Entity      Continent             WHO region  \
# 0.0  ABW          Aruba  North America                    NaN
# 1.0  AFG    Afghanistan           Asia  Eastern Mediterranean
# 2.0  AGO         Angola         Africa                 Africa
# 3.0  AIA       Anguilla  North America                    NaN
# 4.0  ALA  Aland Islands         Europe                    NaN
# ..   ...            ...            ...                    ...
# NaN  TSS            NaN            NaN                    NaN
# NaN  UMC            NaN            NaN                    NaN
# NaN  WLD            NaN            NaN                    NaN
# NaN  XKX            NaN            NaN                    NaN
# NaN  XZN            NaN            NaN                    NaN
#
#     World Region according to the World Bank  \
# 0.0              Latin America and Caribbean
# 1.0                               South Asia
# 2.0                       Sub-Saharan Africa
# 3.0                                      NaN
# 4.0                                      NaN
# ..                                       ...
# NaN                                      NaN
# NaN                                      NaN
# NaN                                      NaN
# NaN                                      NaN
# NaN                                      NaN
#
#     world-regions-according-to-the-united-nations OWID iso2Code  \
# 0.0                   Latin America and Caribbean  ABW       AW
# 1.0                     Central and Southern Asia  AFG       AF
# 2.0                            Sub-Saharan Africa  AGO       AO
# 3.0                   Latin America and Caribbean  AIA      NaN
# 4.0                   Europe and Northern America  ALA      NaN
# ..                                            ...  ...      ...
# NaN                                           NaN  NaN       T6
# NaN                                           NaN  NaN       XT
# NaN                                           NaN  NaN       1W
# NaN                                           NaN  NaN       XK
# NaN                                           NaN  NaN       A5
#
#                                                   name  \
# 0.0                                              Aruba
# 1.0                                        Afghanistan
# 2.0                                             Angola
# 3.0                                                NaN
# 4.0                                                NaN
# ..                                                 ...
# NaN          Sub-Saharan Africa (IDA & IBRD countries)
# NaN                                Upper middle income
# NaN                                              World
# NaN                                             Kosovo
# NaN  Sub-Saharan Africa excluding South Africa and ...
#
#                          region  \
# 0.0  Latin America & Caribbean
# 1.0                  South Asia
# 2.0         Sub-Saharan Africa
# 3.0                         NaN
# 4.0                         NaN
# ..                          ...
# NaN                  Aggregates
# NaN                  Aggregates
# NaN                  Aggregates
# NaN       Europe & Central Asia
# NaN                  Aggregates
#
#                                        adminregion          incomeLevel  \
# 0.0                                                         High income
# 1.0                                     South Asia           Low income
# 2.0     Sub-Saharan Africa (excluding high income)  Lower middle income
# 3.0                                            NaN                  NaN
# 4.0                                            NaN                  NaN
# ..                                             ...                  ...
# NaN                                                          Aggregates
# NaN                                                          Aggregates
# NaN                                                          Aggregates
# NaN  Europe & Central Asia (excluding high income)  Upper middle income
# NaN                                                          Aggregates
#
#         lendingType capitalCity  longitude  latitude   WB
# 0.0  Not classified  Oranjestad   -70.0167  12.51670  ABW
# 1.0             IDA       Kabul    69.1761  34.52280  AFG
# 2.0            IBRD      Luanda    13.2420  -8.81155  AGO
# 3.0             NaN         NaN        NaN       NaN  NaN
# 4.0             NaN         NaN        NaN       NaN  NaN
# ..              ...         ...        ...       ...  ...
# NaN      Aggregates                    NaN       NaN  TSS
# NaN      Aggregates                    NaN       NaN  UMC
# NaN      Aggregates                    NaN       NaN  WLD
# NaN             IDA    Pristina    20.9260  42.56500  XKX
# NaN      Aggregates                    NaN       NaN  XZN
#
# [406 rows x 17 columns]

# %% [markdown]
# In the Excel file, we manually checked if there was any conflict between the World Bank dataset and the OWID dataset, and we also check if there were any duplicate countries.
# The cleaning process with Excel was done in the [custom/ProcessBook.xlsx](/custom/ProcessBook.xlsx) file.
# After finished checking and fixing the datasets, we reloaded the file back to continue.

# %%
df_owid_wb = pd.read_csv(entities_directory + "custom/owid_wb.csv")
df_owid_wb
# Out:
#     Code               Entity Name                    Entity      Continent  \
# 0    ABW                     Aruba                     Aruba  North America
# 1    AFG               Afghanistan               Afghanistan           Asia
# 2    AGO                    Angola                    Angola         Africa
# 3    AIA                  Anguilla                  Anguilla  North America
# 4    ALA             Aland Islands             Aland Islands         Europe
# ..   ...                       ...                       ...            ...
# 391  NaN  St. Kitts-Nevis-Anguilla  St. Kitts-Nevis-Anguilla            NaN
# 392  NaN      U.S. Pacific Islands      U.S. Pacific Islands            NaN
# 393  NaN          U.S. Territories          U.S. Territories            NaN
# 394  NaN               Wake Island               Wake Island            NaN
# 395  NaN            Western Africa            Western Africa            NaN
#
#                 WHO region World Region according to the World Bank  \
# 0                      NaN              Latin America and Caribbean
# 1    Eastern Mediterranean                               South Asia
# 2                   Africa                       Sub-Saharan Africa
# 3                      NaN                                      NaN
# 4                      NaN                                      NaN
# ..                     ...                                      ...
# 391                    NaN                                      NaN
# 392                    NaN                                      NaN
# 393                    NaN                                      NaN
# 394                    NaN                                      NaN
# 395                    NaN                                      NaN
#
#     world-regions-according-to-the-united-nations OWID   WB iso2Code3  \
# 0                     Latin America and Caribbean  ABW  ABW        AW
# 1                       Central and Southern Asia  AFG  AFG        AF
# 2                              Sub-Saharan Africa  AGO  AGO        AO
# 3                     Latin America and Caribbean  AIA  NaN       NaN
# 4                     Europe and Northern America  ALA  NaN       NaN
# ..                                            ...  ...  ...       ...
# 391                                           NaN  NaN  NaN       NaN
# 392                                           NaN  NaN  NaN       NaN
# 393                                           NaN  NaN  NaN       NaN
# 394                                           NaN  NaN  NaN       NaN
# 395                                           NaN  NaN  NaN       NaN
#
#             name                      region  \
# 0          Aruba  Latin America & Caribbean
# 1    Afghanistan                  South Asia
# 2         Angola         Sub-Saharan Africa
# 3            NaN                         NaN
# 4            NaN                         NaN
# ..           ...                         ...
# 391          NaN                         NaN
# 392          NaN                         NaN
# 393          NaN                         NaN
# 394          NaN                         NaN
# 395          NaN                         NaN
#
#                                     adminregion          incomeLevel  \
# 0                                           NaN          High income
# 1                                    South Asia           Low income
# 2    Sub-Saharan Africa (excluding high income)  Lower middle income
# 3                                           NaN                  NaN
# 4                                           NaN                  NaN
# ..                                          ...                  ...
# 391                                         NaN                  NaN
# 392                                         NaN                  NaN
# 393                                         NaN                  NaN
# 394                                         NaN                  NaN
# 395                                         NaN                  NaN
#
#         lendingType capitalCity  longitude  latitude
# 0    Not classified  Oranjestad   -70.0167  12.51670
# 1               IDA       Kabul    69.1761  34.52280
# 2              IBRD      Luanda    13.2420  -8.81155
# 3               NaN         NaN        NaN       NaN
# 4               NaN         NaN        NaN       NaN
# ..              ...         ...        ...       ...
# 391             NaN         NaN        NaN       NaN
# 392             NaN         NaN        NaN       NaN
# 393             NaN         NaN        NaN       NaN
# 394             NaN         NaN        NaN       NaN
# 395             NaN         NaN        NaN       NaN
#
# [396 rows x 18 columns]

# %% [markdown]
# ### Chapter 3: IMF's World Economic Outlook

# %%
# import the Python client
import weo

# read weo dataset
path, url = weo.download(2022, 1, filename = entities_directory + "output/weo_2022_1.csv")

path
url

#  read all countries available in the WEO dataset 
df_weo: pd.DataFrame = weo.WEO(path).countries()
df_weo
# Out:
# Already downloaded 2022-Apr WEO dataset at entities\output\weo_2022_1.csv
#      WEO Country Code  ISO             Country
# 0                 512  AFG         Afghanistan
# 44                914  ALB             Albania
# 88                612  DZA             Algeria
# 132               171  AND             Andorra
# 176               614  AGO              Angola
# ...               ...  ...                 ...
# 8404              582  VNM             Vietnam
# 8448              487  WBG  West Bank and Gaza
# 8492              474  YEM               Yemen
# 8536              754  ZMB              Zambia
# 8580              698  ZWE            Zimbabwe
#
# [196 rows x 3 columns]

# %%
# select only the ISO column and Country column
df_weo = df_weo[["ISO", "Country"]]
df_weo
# Out:
#       ISO             Country
# 0     AFG         Afghanistan
# 44    ALB             Albania
# 88    DZA             Algeria
# 132   AND             Andorra
# 176   AGO              Angola
# ...   ...                 ...
# 8404  VNM             Vietnam
# 8448  WBG  West Bank and Gaza
# 8492  YEM               Yemen
# 8536  ZMB              Zambia
# 8580  ZWE            Zimbabwe
#
# [196 rows x 2 columns]

# %% [markdown]
# #### Merge with WB+OWID dataset

# %%
# store the ISO column to the WEO column to prepare for merging with WB+OWID dataset 
df_weo["WEO"] = df_weo["ISO"]
df_weo

# merge df_weo with df_owid_wb
df = pd.merge(df_owid_wb, df_weo, left_on="Code", right_on="ISO", how="outer")
df

# write the table back to Excel to continue processing
df.to_csv(entities_directory + "output/owid_wb_weo.csv")
df
# after this, I have opened the file in excel and clean the data manually
# Out:
#     Code       Entity Name            Entity      Continent  \
# 0    ABW             Aruba             Aruba  North America
# 1    AFG       Afghanistan       Afghanistan           Asia
# 2    AGO            Angola            Angola         Africa
# 3    AIA          Anguilla          Anguilla  North America
# 4    ALA     Aland Islands     Aland Islands         Europe
# ..   ...               ...               ...            ...
# 393  NaN  U.S. Territories  U.S. Territories            NaN
# 394  NaN       Wake Island       Wake Island            NaN
# 395  NaN    Western Africa    Western Africa            NaN
# 396  NaN               NaN               NaN            NaN
# 397  NaN               NaN               NaN            NaN
#
#                 WHO region World Region according to the World Bank  \
# 0                      NaN              Latin America and Caribbean
# 1    Eastern Mediterranean                               South Asia
# 2                   Africa                       Sub-Saharan Africa
# 3                      NaN                                      NaN
# 4                      NaN                                      NaN
# ..                     ...                                      ...
# 393                    NaN                                      NaN
# 394                    NaN                                      NaN
# 395                    NaN                                      NaN
# 396                    NaN                                      NaN
# 397                    NaN                                      NaN
#
#     world-regions-according-to-the-united-nations OWID   WB iso2Code3  ...  \
# 0                     Latin America and Caribbean  ABW  ABW        AW  ...
# 1                       Central and Southern Asia  AFG  AFG        AF  ...
# 2                              Sub-Saharan Africa  AGO  AGO        AO  ...
# 3                     Latin America and Caribbean  AIA  NaN       NaN  ...
# 4                     Europe and Northern America  ALA  NaN       NaN  ...
# ..                                            ...  ...  ...       ...  ...
# 393                                           NaN  NaN  NaN       NaN  ...
# 394                                           NaN  NaN  NaN       NaN  ...
# 395                                           NaN  NaN  NaN       NaN  ...
# 396                                           NaN  NaN  NaN       NaN  ...
# 397                                           NaN  NaN  NaN       NaN  ...
#
#                          region                                 adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    South Asia                                  South Asia
# 2           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# 3                           NaN                                         NaN
# 4                           NaN                                         NaN
# ..                          ...                                         ...
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
# 396                         NaN                                         NaN
# 397                         NaN                                         NaN
#
#              incomeLevel     lendingType capitalCity longitude  latitude  ISO  \
# 0            High income  Not classified  Oranjestad  -70.0167  12.51670  ABW
# 1             Low income             IDA       Kabul   69.1761  34.52280  AFG
# 2    Lower middle income            IBRD      Luanda   13.2420  -8.81155  AGO
# 3                    NaN             NaN         NaN       NaN       NaN  NaN
# 4                    NaN             NaN         NaN       NaN       NaN  NaN
# ..                   ...             ...         ...       ...       ...  ...
# 393                  NaN             NaN         NaN       NaN       NaN  NaN
# 394                  NaN             NaN         NaN       NaN       NaN  NaN
# 395                  NaN             NaN         NaN       NaN       NaN  NaN
# 396                  NaN             NaN         NaN       NaN       NaN  UVK
# 397                  NaN             NaN         NaN       NaN       NaN  WBG
#
#                 Country  WEO
# 0                 Aruba  ABW
# 1           Afghanistan  AFG
# 2                Angola  AGO
# 3                   NaN  NaN
# 4                   NaN  NaN
# ..                  ...  ...
# 393                 NaN  NaN
# 394                 NaN  NaN
# 395                 NaN  NaN
# 396              Kosovo  UVK
# 397  West Bank and Gaza  WBG
#
# [398 rows x 21 columns]

# %% [markdown]
# In the Excel file, we checked for conflicts between WEO, WB, and OWID, and check if there were any duplicate countries in the file.
# The cleaning process with Excel was done in the [custom/ProcessBook.xlsx](/custom/ProcessBook.xlsx) file.
# After finished checking and fixing the datasets, we put the final processed dataset in the entities sheet.
# We reload the file back to finalize.

# %% [markdown]
# ### Final
# Finally, we moved the final dataset in the "entities" Excel sheet to the front, stored it in a csv.

# %%
# load the sheet back to df, and write the data to entities.csv
df = pd.read_excel(entities_directory + "custom/ProcessBook.xlsx", sheet_name="entities")
df.to_csv(entities_directory + "entities.csv", index=False)
df
# Out:
#     Code                       Entity OWID    OWID_Name OWID_Continent  \
# 0    ABW                        Aruba  ABW        Aruba  North America
# 1    AFE  Africa Eastern and Southern  NaN          NaN            NaN
# 2    AFG                  Afghanistan  AFG  Afghanistan           Asia
# 3    AFW   Africa Western and Central  NaN          NaN            NaN
# 4    AGO                       Angola  AGO       Angola         Africa
# ..   ...                          ...  ...          ...            ...
# 391  NaN                  Wake Island  NaN  Wake Island            NaN
# 392  NaN                     Non-OECD  NaN     Non-OECD            NaN
# 393  NaN                      Oceania  NaN      Oceania            NaN
# 394  NaN                         Asia  NaN         Asia            NaN
# 395  NaN                          CIS  NaN          CIS            NaN
#
#            OWID_WHO_Region               OWID_WB_Region  \
# 0                      NaN  Latin America and Caribbean
# 1                      NaN                          NaN
# 2    Eastern Mediterranean                   South Asia
# 3                      NaN                          NaN
# 4                   Africa           Sub-Saharan Africa
# ..                     ...                          ...
# 391                    NaN                          NaN
# 392                    NaN                          NaN
# 393                    NaN                          NaN
# 394                    NaN                          NaN
# 395                    NaN                          NaN
#
#                   OWID_UN_Region   WB WB_ISO2                      WB_Name  \
# 0    Latin America and Caribbean  ABW      AW                        Aruba
# 1                            NaN  AFE      ZH  Africa Eastern and Southern
# 2      Central and Southern Asia  AFG      AF                  Afghanistan
# 3                            NaN  AFW      ZI   Africa Western and Central
# 4             Sub-Saharan Africa  AGO      AO                       Angola
# ..                           ...  ...     ...                          ...
# 391                          NaN  NaN     NaN                          NaN
# 392                          NaN  NaN     NaN                          NaN
# 393                          NaN  NaN     NaN                          NaN
# 394                          NaN  NaN     NaN                          NaN
# 395                          NaN  NaN     NaN                          NaN
#
#                       WB_region                              WB_adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#           WB_incomeLevel  WB_lendingType WB_capitalCity  WB_longitude  \
# 0            High income  Not classified     Oranjestad      -70.0167
# 1             Aggregates      Aggregates            NaN           NaN
# 2             Low income             IDA          Kabul       69.1761
# 3             Aggregates      Aggregates            NaN           NaN
# 4    Lower middle income            IBRD         Luanda       13.2420
# ..                   ...             ...            ...           ...
# 391                  NaN             NaN            NaN           NaN
# 392                  NaN             NaN            NaN           NaN
# 393                  NaN             NaN            NaN           NaN
# 394                  NaN             NaN            NaN           NaN
# 395                  NaN             NaN            NaN           NaN
#
#      WB_latitude  WEO  WEO_Country
# 0       12.51670  ABW        Aruba
# 1            NaN  NaN          NaN
# 2       34.52280  AFG  Afghanistan
# 3            NaN  NaN          NaN
# 4       -8.81155  AGO       Angola
# ..           ...  ...          ...
# 391          NaN  NaN          NaN
# 392          NaN  NaN          NaN
# 393          NaN  NaN          NaN
# 394          NaN  NaN          NaN
# 395          NaN  NaN          NaN
#
# [396 rows x 20 columns]

# %% [markdown]
# ## Data Dictionary (Info)
#
# The script used in this section serves as a method to convert the info.xlsx Excel book into a json file to be loaded into the web.

# %%
import pandas as pd

info_directory = "info/"

df_info = pd.read_excel(info_directory + "info.xlsx", sheet_name="info")
df_info.set_index("value", drop=False, inplace=True)

df_order = pd.read_excel(info_directory + "info.xlsx", sheet_name="order")
df_order = df_order.apply(lambda x: x.dropna().tolist()).to_frame("order")

df = pd.merge(df_info, df_order, left_index=True, right_index=True, how="left")
df.agg(lambda x: x.dropna().to_dict(), axis=1).to_json(info_directory + "info.json")

# %% [markdown]
# ## Final Energy Dataset
#
# This notebook will document the entire creation of the final Countries Stats and Energy use dataset.
# The dataset is sourced from Our World in Data's Energy Data and World Bank's Datasets.
#
# The variables and documentation for this dataset can be found in the `info.xlsx` Excel workbook in the `info` directory.

# %%
# import needed packages
import pandas as pd
import world_bank_data as wb

# %% [markdown]
# ### Entities

# %%
# read entities dataset
df_entities = pd.read_csv("entities/entities.csv")
df_entities
# Out:
#     Code                       Entity OWID    OWID_Name OWID_Continent  \
# 0    ABW                        Aruba  ABW        Aruba  North America
# 1    AFE  Africa Eastern and Southern  NaN          NaN            NaN
# 2    AFG                  Afghanistan  AFG  Afghanistan           Asia
# 3    AFW   Africa Western and Central  NaN          NaN            NaN
# 4    AGO                       Angola  AGO       Angola         Africa
# ..   ...                          ...  ...          ...            ...
# 391  NaN                  Wake Island  NaN  Wake Island            NaN
# 392  NaN                     Non-OECD  NaN     Non-OECD            NaN
# 393  NaN                      Oceania  NaN      Oceania            NaN
# 394  NaN                         Asia  NaN         Asia            NaN
# 395  NaN                          CIS  NaN          CIS            NaN
#
#            OWID_WHO_Region               OWID_WB_Region  \
# 0                      NaN  Latin America and Caribbean
# 1                      NaN                          NaN
# 2    Eastern Mediterranean                   South Asia
# 3                      NaN                          NaN
# 4                   Africa           Sub-Saharan Africa
# ..                     ...                          ...
# 391                    NaN                          NaN
# 392                    NaN                          NaN
# 393                    NaN                          NaN
# 394                    NaN                          NaN
# 395                    NaN                          NaN
#
#                   OWID_UN_Region   WB WB_ISO2                      WB_Name  \
# 0    Latin America and Caribbean  ABW      AW                        Aruba
# 1                            NaN  AFE      ZH  Africa Eastern and Southern
# 2      Central and Southern Asia  AFG      AF                  Afghanistan
# 3                            NaN  AFW      ZI   Africa Western and Central
# 4             Sub-Saharan Africa  AGO      AO                       Angola
# ..                           ...  ...     ...                          ...
# 391                          NaN  NaN     NaN                          NaN
# 392                          NaN  NaN     NaN                          NaN
# 393                          NaN  NaN     NaN                          NaN
# 394                          NaN  NaN     NaN                          NaN
# 395                          NaN  NaN     NaN                          NaN
#
#                       WB_region                              WB_adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#           WB_incomeLevel  WB_lendingType WB_capitalCity  WB_longitude  \
# 0            High income  Not classified     Oranjestad      -70.0167
# 1             Aggregates      Aggregates            NaN           NaN
# 2             Low income             IDA          Kabul       69.1761
# 3             Aggregates      Aggregates            NaN           NaN
# 4    Lower middle income            IBRD         Luanda       13.2420
# ..                   ...             ...            ...           ...
# 391                  NaN             NaN            NaN           NaN
# 392                  NaN             NaN            NaN           NaN
# 393                  NaN             NaN            NaN           NaN
# 394                  NaN             NaN            NaN           NaN
# 395                  NaN             NaN            NaN           NaN
#
#      WB_latitude  WEO  WEO_Country
# 0       12.51670  ABW        Aruba
# 1            NaN  NaN          NaN
# 2       34.52280  AFG  Afghanistan
# 3            NaN  NaN          NaN
# 4       -8.81155  AGO       Angola
# ..           ...  ...          ...
# 391          NaN  NaN          NaN
# 392          NaN  NaN          NaN
# 393          NaN  NaN          NaN
# 394          NaN  NaN          NaN
# 395          NaN  NaN          NaN
#
# [396 rows x 20 columns]

# %% [markdown]
# ### Our World in Data

# %%
# load the dataset
df_owid = pd.read_csv("https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv")
df_owid
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17234      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17235      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17236      ZWE     Zimbabwe  2018                14.336                 3.148
# 17237      ZWE     Zimbabwe  2019               -21.529                -5.405
# 17238      ZWE     Zimbabwe  2020                24.859                 4.897
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 17234                  NaN                  0.0                  NaN
# 17235                  NaN                  NaN                  NaN
# 17236                  NaN                  NaN                  NaN
# 17237                  NaN                  NaN                  NaN
# 17238                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  ...  solar_consumption  \
# 0                      NaN                     NaN  ...                NaN
# 1                      NaN                     NaN  ...                NaN
# 2                      NaN                     NaN  ...                NaN
# 3                      NaN                     NaN  ...                NaN
# 4                      NaN                     NaN  ...                NaN
# ...                    ...                     ...  ...                ...
# 17234                  0.0                 -14.611  ...                NaN
# 17235                  NaN                  -1.564  ...                NaN
# 17236                  NaN                   3.409  ...                NaN
# 17237                  NaN                   4.052  ...                NaN
# 17238                  NaN                     NaN  ...                NaN
#
#        solar_elec_per_capita  solar_energy_per_capita  wind_share_elec  \
# 0                        NaN                      NaN              NaN
# 1                        NaN                      NaN              NaN
# 2                        NaN                      NaN              NaN
# 3                        NaN                      NaN              NaN
# 4                        NaN                      NaN              NaN
# ...                      ...                      ...              ...
# 17234                  0.713                      NaN              0.0
# 17235                  0.702                      NaN              0.0
# 17236                  0.693                      NaN              0.0
# 17237                  0.683                      NaN              0.0
# 17238                  0.673                      NaN              0.0
#
#        wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# 0                       NaN                NaN                   NaN
# 1                       NaN                NaN                   NaN
# 2                       NaN                NaN                   NaN
# 3                       NaN                NaN                   NaN
# 4                       NaN                NaN                   NaN
# ...                     ...                ...                   ...
# 17234                   NaN                NaN                   NaN
# 17235                   NaN                NaN                   NaN
# 17236                   NaN                NaN                   NaN
# 17237                   NaN                NaN                   NaN
# 17238                   NaN                NaN                   NaN
#
#        wind_consumption  wind_elec_per_capita  wind_energy_per_capita
# 0                   NaN                   NaN                     NaN
# 1                   NaN                   NaN                     NaN
# 2                   NaN                   NaN                     NaN
# 3                   NaN                   NaN                     NaN
# 4                   NaN                   NaN                     NaN
# ...                 ...                   ...                     ...
# 17234               NaN                   0.0                     NaN
# 17235               NaN                   0.0                     NaN
# 17236               NaN                   0.0                     NaN
# 17237               NaN                   0.0                     NaN
# 17238               NaN                   0.0                     NaN
#
# [17239 rows x 128 columns]

# %% [markdown]
# #### Transform data

# %%
# transform data

# transform year to int data type
# this is so that iso_code + year can be compatible primary keys with the world bank dataset
df_owid["year"] = df_owid["year"].transform(int)
df_owid

# remove country column
# We already have defined the country names in the "entities" table
df_owid.drop(columns="country", inplace=True)
df_owid
# Out:
#       iso_code  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  1900                   NaN                   NaN
# 1          AFG  1901                   NaN                 0.000
# 2          AFG  1902                   NaN                 0.000
# 3          AFG  1903                   NaN                 0.000
# 4          AFG  1904                   NaN                 0.000
# ...        ...   ...                   ...                   ...
# 17234      ZWE  2016               -37.694               -12.257
# 17235      ZWE  2017                 8.375                 1.697
# 17236      ZWE  2018                14.336                 3.148
# 17237      ZWE  2019               -21.529                -5.405
# 17238      ZWE  2020                24.859                 4.897
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 17234                  NaN                  0.0                  NaN
# 17235                  NaN                  NaN                  NaN
# 17236                  NaN                  NaN                  NaN
# 17237                  NaN                  NaN                  NaN
# 17238                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  energy_cons_change_twh  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
# ...                    ...                     ...                     ...
# 17234                  0.0                 -14.611                  -7.985
# 17235                  NaN                  -1.564                  -0.730
# 17236                  NaN                   3.409                   1.566
# 17237                  NaN                   4.052                   1.925
# 17238                  NaN                     NaN                     NaN
#
#        ...  solar_consumption  solar_elec_per_capita  solar_energy_per_capita  \
# 0      ...                NaN                    NaN                      NaN
# 1      ...                NaN                    NaN                      NaN
# 2      ...                NaN                    NaN                      NaN
# 3      ...                NaN                    NaN                      NaN
# 4      ...                NaN                    NaN                      NaN
# ...    ...                ...                    ...                      ...
# 17234  ...                NaN                  0.713                      NaN
# 17235  ...                NaN                  0.702                      NaN
# 17236  ...                NaN                  0.693                      NaN
# 17237  ...                NaN                  0.683                      NaN
# 17238  ...                NaN                  0.673                      NaN
#
#        wind_share_elec  wind_cons_change_pct  wind_share_energy  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
# ...                ...                   ...                ...
# 17234              0.0                   NaN                NaN
# 17235              0.0                   NaN                NaN
# 17236              0.0                   NaN                NaN
# 17237              0.0                   NaN                NaN
# 17238              0.0                   NaN                NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 17234                   NaN               NaN                   0.0
# 17235                   NaN               NaN                   0.0
# 17236                   NaN               NaN                   0.0
# 17237                   NaN               NaN                   0.0
# 17238                   NaN               NaN                   0.0
#
#        wind_energy_per_capita
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17234                     NaN
# 17235                     NaN
# 17236                     NaN
# 17237                     NaN
# 17238                     NaN
#
# [17239 rows x 127 columns]

# %% [markdown]
# ##### Transform iso_code to Entities Code

# %%
# transform iso code to Entities Code

# df_entities Code and OWID
df_entities[["Code", "OWID"]]

#  merge df_owid with df_entities[["Code", "OWID"]]
df_owid = pd.merge(df_entities[["Code", "OWID"]], df_owid, how="right", left_on="Code", right_on="iso_code")
df_owid

# transform iso_code to standard df_entities Code
df_owid["iso_code"] = df_owid["Code"]
df_owid

# remove Code and OWID
# we can ensure that this cannot affect the original OWID dataset, since there is no variable in the dataset name "Code" or "OWID"
df_owid.drop(columns=["Code", "OWID"], inplace=True)
df_owid
# Out:
#       iso_code  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  1900                   NaN                   NaN
# 1          AFG  1901                   NaN                 0.000
# 2          AFG  1902                   NaN                 0.000
# 3          AFG  1903                   NaN                 0.000
# 4          AFG  1904                   NaN                 0.000
# ...        ...   ...                   ...                   ...
# 47177      ZWE  2016               -37.694               -12.257
# 47178      ZWE  2017                 8.375                 1.697
# 47179      ZWE  2018                14.336                 3.148
# 47180      ZWE  2019               -21.529                -5.405
# 47181      ZWE  2020                24.859                 4.897
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 47177                  NaN                  0.0                  NaN
# 47178                  NaN                  NaN                  NaN
# 47179                  NaN                  NaN                  NaN
# 47180                  NaN                  NaN                  NaN
# 47181                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  energy_cons_change_twh  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
# ...                    ...                     ...                     ...
# 47177                  0.0                 -14.611                  -7.985
# 47178                  NaN                  -1.564                  -0.730
# 47179                  NaN                   3.409                   1.566
# 47180                  NaN                   4.052                   1.925
# 47181                  NaN                     NaN                     NaN
#
#        ...  solar_consumption  solar_elec_per_capita  solar_energy_per_capita  \
# 0      ...                NaN                    NaN                      NaN
# 1      ...                NaN                    NaN                      NaN
# 2      ...                NaN                    NaN                      NaN
# 3      ...                NaN                    NaN                      NaN
# 4      ...                NaN                    NaN                      NaN
# ...    ...                ...                    ...                      ...
# 47177  ...                NaN                  0.713                      NaN
# 47178  ...                NaN                  0.702                      NaN
# 47179  ...                NaN                  0.693                      NaN
# 47180  ...                NaN                  0.683                      NaN
# 47181  ...                NaN                  0.673                      NaN
#
#        wind_share_elec  wind_cons_change_pct  wind_share_energy  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
# ...                ...                   ...                ...
# 47177              0.0                   NaN                NaN
# 47178              0.0                   NaN                NaN
# 47179              0.0                   NaN                NaN
# 47180              0.0                   NaN                NaN
# 47181              0.0                   NaN                NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 47177                   NaN               NaN                   0.0
# 47178                   NaN               NaN                   0.0
# 47179                   NaN               NaN                   0.0
# 47180                   NaN               NaN                   0.0
# 47181                   NaN               NaN                   0.0
#
#        wind_energy_per_capita
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 47177                     NaN
# 47178                     NaN
# 47179                     NaN
# 47180                     NaN
# 47181                     NaN
#
# [47182 rows x 127 columns]

# %% [markdown]
# #### Melt the dataset

# %%
# melt dataset and remove nan values

# melt the dataset
df_owid = pd.melt(df_owid, id_vars=["iso_code", "year"], var_name="attr", value_name="owid")
df_owid

# remove nan values
df_owid.dropna(inplace=True)
df_owid
# Out:
#          iso_code  year                    attr     owid
# 50            AFG  1950    coal_prod_change_pct  180.000
# 51            AFG  1951    coal_prod_change_pct    7.143
# 52            AFG  1952    coal_prod_change_pct   13.333
# 53            AFG  1953    coal_prod_change_pct   -5.882
# 54            AFG  1954    coal_prod_change_pct   -6.250
# ...           ...   ...                     ...      ...
# 5894875  OWID_WRL  2016  wind_energy_per_capita  324.182
# 5894876  OWID_WRL  2017  wind_energy_per_capita  377.678
# 5894877  OWID_WRL  2018  wind_energy_per_capita  413.472
# 5894878  OWID_WRL  2019  wind_energy_per_capita  455.268
# 5894879  OWID_WRL  2020  wind_energy_per_capita  503.633
#
# [682397 rows x 4 columns]

# %% [markdown]
# ### World Bank

# %% [markdown]
# #### Sample Code

# %%
# get series
# the output is a Series with MultiLevel Index 
# id or value is id, meaning that the Country value will be the ISO code instead of name, and Series value will be Indicator Code instead of Indicator name
df_sample: pd.Series = wb.get_series(indicator="AG.LND.TOTL.K2", id_or_value="id")
df_sample
# Out:
# Country  Series          Year
# AFE      AG.LND.TOTL.K2  1960             NaN
#                          1961    1.477796e+07
#                          1962    1.477796e+07
#                          1963    1.477796e+07
#                          1964    1.477796e+07
#                                      ...
# ZWE      AG.LND.TOTL.K2  2017    3.868500e+05
#                          2018    3.868500e+05
#                          2019    3.868500e+05
#                          2020    3.868500e+05
#                          2021    3.868500e+05
# Name: AG.LND.TOTL.K2, Length: 16492, dtype: float64

# %%
# transform the series to dataframe with name "Value". The name will be the value column name when transformed to normal table
df_sample = df_sample.to_frame("Value")
df_sample
# Out:
#                                     Value
# Country Series         Year
# AFE     AG.LND.TOTL.K2 1960           NaN
#                        1961  1.477796e+07
#                        1962  1.477796e+07
#                        1963  1.477796e+07
#                        1964  1.477796e+07
# ...                                   ...
# ZWE     AG.LND.TOTL.K2 2017  3.868500e+05
#                        2018  3.868500e+05
#                        2019  3.868500e+05
#                        2020  3.868500e+05
#                        2021  3.868500e+05
#
# [16492 rows x 1 columns]

# %%
# reset index in order to change the MultiLevel Index column format to a normal column format
df_sample.reset_index(inplace=True)
df_sample
# Out:
#       Country          Series  Year         Value
# 0         AFE  AG.LND.TOTL.K2  1960           NaN
# 1         AFE  AG.LND.TOTL.K2  1961  1.477796e+07
# 2         AFE  AG.LND.TOTL.K2  1962  1.477796e+07
# 3         AFE  AG.LND.TOTL.K2  1963  1.477796e+07
# 4         AFE  AG.LND.TOTL.K2  1964  1.477796e+07
# ...       ...             ...   ...           ...
# 16487     ZWE  AG.LND.TOTL.K2  2017  3.868500e+05
# 16488     ZWE  AG.LND.TOTL.K2  2018  3.868500e+05
# 16489     ZWE  AG.LND.TOTL.K2  2019  3.868500e+05
# 16490     ZWE  AG.LND.TOTL.K2  2020  3.868500e+05
# 16491     ZWE  AG.LND.TOTL.K2  2021  3.868500e+05
#
# [16492 rows x 4 columns]

# %%
# end sample code
del df_sample

# %% [markdown]
# #### Collect data

# %%
# set a dictionary of indicator codes
# each value of the indicator code is the name of the variable in our final dataset
IndicatorCodes = {
    "AG.LND.TOTL.K2": "area",
    "SP.POP.TOTL": "population",
    "NY.GDP.MKTP.CD": "gdp",
    "NY.GDP.MKTP.PP.CD": "gdp_ppp",
    "NY.GDP.PCAP.CD": "gdp_per_captia",
    "NY.GDP.PCAP.PP.CD": "gdp_ppp_per_capita",
}

# get all indicator codes datasets
list_df = []

for indicator_code in IndicatorCodes:
    # get series
    df: pd.Series = wb.get_series(indicator=indicator_code, id_or_value="id")
    # trasnform to dataframe with name Value
    df = df.to_frame("Value")
    # reset index to transform into a normal
    df.reset_index(inplace=True)
    # add to df list
    list_df.append(df)

df_wb = pd.concat(list_df)
df_wb

# then, delete unwanted values
del list_df, df, indicator_code

# %% [markdown]
# #### Transform data

# %%
# transform data

# rename "Series" value 
# in order to match variable value with OWID data
df_wb["Series"] = df_wb["Series"].transform(lambda x: IndicatorCodes[x])
df_wb

# remove nan values
df_wb.dropna(inplace=True)
df_wb

# rename column, prepare to join with df_owid
df_wb.rename(columns={
    "Country": "iso_code",
    "Year": "year",
    "Series": "attr",
    "Value": "wb"
}, inplace=True)
df_wb

# transform year to int data type
# this is so that iso_code + year can be compatible primary keys with the owid dataset
df_wb["year"] = df_wb["year"].transform(int)
df_wb
# Out:
#       iso_code                attr  year            wb
# 1          AFE                area  1961  1.477796e+07
# 2          AFE                area  1962  1.477796e+07
# 3          AFE                area  1963  1.477796e+07
# 4          AFE                area  1964  1.477796e+07
# 5          AFE                area  1965  1.477796e+07
# ...        ...                 ...   ...           ...
# 16486      ZWE  gdp_ppp_per_capita  2016  2.806469e+03
# 16487      ZWE  gdp_ppp_per_capita  2017  3.795642e+03
# 16488      ZWE  gdp_ppp_per_capita  2018  4.017222e+03
# 16489      ZWE  gdp_ppp_per_capita  2019  3.783548e+03
# 16490      ZWE  gdp_ppp_per_capita  2020  3.537351e+03
#
# [72259 rows x 4 columns]

# %% [markdown]
# #### Transform iso_code to Entity Code

# %%
# transform iso code to entity code

# df_entities Code and OWID
df_entities[["Code", "WB"]]

#  merge df_owid with df_entities[["Code", "OWID"]]
df_wb = pd.merge(df_entities[["Code", "WB"]], df_wb, how="right", left_on="Code", right_on="iso_code")
df_wb

# transform iso_code to standard df_entities Code
df_wb["iso_code"] = df_wb["Code"]
df_wb

# remove Code and WB
df_wb.drop(columns=["Code", "WB"], inplace=True)
df_wb

# remove nan values
df_wb.dropna(inplace=True)
df_wb
# Out:
#       iso_code                attr  year            wb
# 0          AFE                area  1961  1.477796e+07
# 1          AFE                area  1962  1.477796e+07
# 2          AFE                area  1963  1.477796e+07
# 3          AFE                area  1964  1.477796e+07
# 4          AFE                area  1965  1.477796e+07
# ...        ...                 ...   ...           ...
# 72254      ZWE  gdp_ppp_per_capita  2016  2.806469e+03
# 72255      ZWE  gdp_ppp_per_capita  2017  3.795642e+03
# 72256      ZWE  gdp_ppp_per_capita  2018  4.017222e+03
# 72257      ZWE  gdp_ppp_per_capita  2019  3.783548e+03
# 72258      ZWE  gdp_ppp_per_capita  2020  3.537351e+03
#
# [71641 rows x 4 columns]

# %% [markdown]
# #### Merge OWID and WB data

# %%
# merge owid and wb data

# merge df_owid with df_wb
df = pd.merge(df_owid, df_wb, how="outer", on=["iso_code", "year", "attr"])
df

# merge two values from two different datasets
# we prioritize wb values
df["value"] = df["wb"].fillna(df["owid"])
df

# remove owid and wb, only keep value
df = df[["iso_code", "year", "attr", "value"]]
df
# Out:
#        iso_code  year                  attr        value
# 0           AFG  1950  coal_prod_change_pct   180.000000
# 1           AFG  1951  coal_prod_change_pct     7.143000
# 2           AFG  1952  coal_prod_change_pct    13.333000
# 3           AFG  1953  coal_prod_change_pct    -5.882000
# 4           AFG  1954  coal_prod_change_pct    -6.250000
# ...         ...   ...                   ...          ...
# 736790      ZWE  2016    gdp_ppp_per_capita  2806.469032
# 736791      ZWE  2017    gdp_ppp_per_capita  3795.642431
# 736792      ZWE  2018    gdp_ppp_per_capita  4017.221716
# 736793      ZWE  2019    gdp_ppp_per_capita  3783.547898
# 736794      ZWE  2020    gdp_ppp_per_capita  3537.351394
#
# [736795 rows x 4 columns]

# %% [markdown]
# ### Entities Groups

# %%
# variables needed
# variables name and matching column in Entities dataset
vars = {
    "iso_code": "Code",
    "country": "Entity",
    "group_OWID_Continent": "OWID_Continent",
    "group_UN_Region": "OWID_UN_Region",
    "group_WHO_Region": "OWID_WHO_Region",
    "group_WB_region": "WB_region",
    "group_WB_adminregion": "WB_adminregion",
    "group_WB_incomeLevel": "WB_incomeLevel",
    "group_WB_lendingType": "WB_lendingType",
    "group_WB_longitude": "WB_longitude",
    "group_WB_latitude": "WB_latitude"
}

# variables of group type
# each of these variable will have a twin variable with the US's value always equals United States
# this is so that in the visualisation, the US can be highlighted
vars_group = [
    "group_OWID_Continent",
    "group_UN_Region",
    "group_WHO_Region",
    "group_WB_region",
    "group_WB_adminregion",
    "group_WB_incomeLevel",
    "group_WB_lendingType"
]

# %%
# create df_groups

df_groups = pd.DataFrame()

for k in vars:

    df_groups[k] = df_entities[vars[k]]

df_groups
# Out:
#     iso_code                      country group_OWID_Continent  \
# 0        ABW                        Aruba        North America
# 1        AFE  Africa Eastern and Southern                  NaN
# 2        AFG                  Afghanistan                 Asia
# 3        AFW   Africa Western and Central                  NaN
# 4        AGO                       Angola               Africa
# ..       ...                          ...                  ...
# 391      NaN                  Wake Island                  NaN
# 392      NaN                     Non-OECD                  NaN
# 393      NaN                      Oceania                  NaN
# 394      NaN                         Asia                  NaN
# 395      NaN                          CIS                  NaN
#
#                  group_UN_Region       group_WHO_Region  \
# 0    Latin America and Caribbean                    NaN
# 1                            NaN                    NaN
# 2      Central and Southern Asia  Eastern Mediterranean
# 3                            NaN                    NaN
# 4             Sub-Saharan Africa                 Africa
# ..                           ...                    ...
# 391                          NaN                    NaN
# 392                          NaN                    NaN
# 393                          NaN                    NaN
# 394                          NaN                    NaN
# 395                          NaN                    NaN
#
#                 group_WB_region                        group_WB_adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#     group_WB_incomeLevel group_WB_lendingType  group_WB_longitude  \
# 0            High income       Not classified            -70.0167
# 1             Aggregates           Aggregates                 NaN
# 2             Low income                  IDA             69.1761
# 3             Aggregates           Aggregates                 NaN
# 4    Lower middle income                 IBRD             13.2420
# ..                   ...                  ...                 ...
# 391                  NaN                  NaN                 NaN
# 392                  NaN                  NaN                 NaN
# 393                  NaN                  NaN                 NaN
# 394                  NaN                  NaN                 NaN
# 395                  NaN                  NaN                 NaN
#
#      group_WB_latitude
# 0             12.51670
# 1                  NaN
# 2             34.52280
# 3                  NaN
# 4             -8.81155
# ..                 ...
# 391                NaN
# 392                NaN
# 393                NaN
# 394                NaN
# 395                NaN
#
# [396 rows x 11 columns]

# %%
# add twin attributes that prioritize US

for k in vars_group:

    df_groups[k + "_exclude_US"] = df_groups[k]

    df_groups.loc[df_groups["country"] == "United States", k + "_exclude_US"] = "United States"

df_groups
# Out:
#     iso_code                      country group_OWID_Continent  \
# 0        ABW                        Aruba        North America
# 1        AFE  Africa Eastern and Southern                  NaN
# 2        AFG                  Afghanistan                 Asia
# 3        AFW   Africa Western and Central                  NaN
# 4        AGO                       Angola               Africa
# ..       ...                          ...                  ...
# 391      NaN                  Wake Island                  NaN
# 392      NaN                     Non-OECD                  NaN
# 393      NaN                      Oceania                  NaN
# 394      NaN                         Asia                  NaN
# 395      NaN                          CIS                  NaN
#
#                  group_UN_Region       group_WHO_Region  \
# 0    Latin America and Caribbean                    NaN
# 1                            NaN                    NaN
# 2      Central and Southern Asia  Eastern Mediterranean
# 3                            NaN                    NaN
# 4             Sub-Saharan Africa                 Africa
# ..                           ...                    ...
# 391                          NaN                    NaN
# 392                          NaN                    NaN
# 393                          NaN                    NaN
# 394                          NaN                    NaN
# 395                          NaN                    NaN
#
#                 group_WB_region                        group_WB_adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#     group_WB_incomeLevel group_WB_lendingType  group_WB_longitude  \
# 0            High income       Not classified            -70.0167
# 1             Aggregates           Aggregates                 NaN
# 2             Low income                  IDA             69.1761
# 3             Aggregates           Aggregates                 NaN
# 4    Lower middle income                 IBRD             13.2420
# ..                   ...                  ...                 ...
# 391                  NaN                  NaN                 NaN
# 392                  NaN                  NaN                 NaN
# 393                  NaN                  NaN                 NaN
# 394                  NaN                  NaN                 NaN
# 395                  NaN                  NaN                 NaN
#
#      group_WB_latitude group_OWID_Continent_exclude_US  \
# 0             12.51670                   North America
# 1                  NaN                             NaN
# 2             34.52280                            Asia
# 3                  NaN                             NaN
# 4             -8.81155                          Africa
# ..                 ...                             ...
# 391                NaN                             NaN
# 392                NaN                             NaN
# 393                NaN                             NaN
# 394                NaN                             NaN
# 395                NaN                             NaN
#
#       group_UN_Region_exclude_US group_WHO_Region_exclude_US  \
# 0    Latin America and Caribbean                         NaN
# 1                            NaN                         NaN
# 2      Central and Southern Asia       Eastern Mediterranean
# 3                            NaN                         NaN
# 4             Sub-Saharan Africa                      Africa
# ..                           ...                         ...
# 391                          NaN                         NaN
# 392                          NaN                         NaN
# 393                          NaN                         NaN
# 394                          NaN                         NaN
# 395                          NaN                         NaN
#
#      group_WB_region_exclude_US             group_WB_adminregion_exclude_US  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#     group_WB_incomeLevel_exclude_US group_WB_lendingType_exclude_US
# 0                       High income                  Not classified
# 1                        Aggregates                      Aggregates
# 2                        Low income                             IDA
# 3                        Aggregates                      Aggregates
# 4               Lower middle income                            IBRD
# ..                              ...                             ...
# 391                             NaN                             NaN
# 392                             NaN                             NaN
# 393                             NaN                             NaN
# 394                             NaN                             NaN
# 395                             NaN                             NaN
#
# [396 rows x 18 columns]

# %%
# add a variable that equals United States if and only if the Entity is United States

df_groups["group_is_USA"] = df_groups["country"].copy(deep=True).transform(lambda x: x if x == "United States" else "Other Entities")

df_groups
# Out:
#     iso_code                      country group_OWID_Continent  \
# 0        ABW                        Aruba        North America
# 1        AFE  Africa Eastern and Southern                  NaN
# 2        AFG                  Afghanistan                 Asia
# 3        AFW   Africa Western and Central                  NaN
# 4        AGO                       Angola               Africa
# ..       ...                          ...                  ...
# 391      NaN                  Wake Island                  NaN
# 392      NaN                     Non-OECD                  NaN
# 393      NaN                      Oceania                  NaN
# 394      NaN                         Asia                  NaN
# 395      NaN                          CIS                  NaN
#
#                  group_UN_Region       group_WHO_Region  \
# 0    Latin America and Caribbean                    NaN
# 1                            NaN                    NaN
# 2      Central and Southern Asia  Eastern Mediterranean
# 3                            NaN                    NaN
# 4             Sub-Saharan Africa                 Africa
# ..                           ...                    ...
# 391                          NaN                    NaN
# 392                          NaN                    NaN
# 393                          NaN                    NaN
# 394                          NaN                    NaN
# 395                          NaN                    NaN
#
#                 group_WB_region                        group_WB_adminregion  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#     group_WB_incomeLevel group_WB_lendingType  group_WB_longitude  \
# 0            High income       Not classified            -70.0167
# 1             Aggregates           Aggregates                 NaN
# 2             Low income                  IDA             69.1761
# 3             Aggregates           Aggregates                 NaN
# 4    Lower middle income                 IBRD             13.2420
# ..                   ...                  ...                 ...
# 391                  NaN                  NaN                 NaN
# 392                  NaN                  NaN                 NaN
# 393                  NaN                  NaN                 NaN
# 394                  NaN                  NaN                 NaN
# 395                  NaN                  NaN                 NaN
#
#      group_WB_latitude group_OWID_Continent_exclude_US  \
# 0             12.51670                   North America
# 1                  NaN                             NaN
# 2             34.52280                            Asia
# 3                  NaN                             NaN
# 4             -8.81155                          Africa
# ..                 ...                             ...
# 391                NaN                             NaN
# 392                NaN                             NaN
# 393                NaN                             NaN
# 394                NaN                             NaN
# 395                NaN                             NaN
#
#       group_UN_Region_exclude_US group_WHO_Region_exclude_US  \
# 0    Latin America and Caribbean                         NaN
# 1                            NaN                         NaN
# 2      Central and Southern Asia       Eastern Mediterranean
# 3                            NaN                         NaN
# 4             Sub-Saharan Africa                      Africa
# ..                           ...                         ...
# 391                          NaN                         NaN
# 392                          NaN                         NaN
# 393                          NaN                         NaN
# 394                          NaN                         NaN
# 395                          NaN                         NaN
#
#      group_WB_region_exclude_US             group_WB_adminregion_exclude_US  \
# 0    Latin America & Caribbean                                          NaN
# 1                    Aggregates                                         NaN
# 2                    South Asia                                  South Asia
# 3                    Aggregates                                         NaN
# 4           Sub-Saharan Africa   Sub-Saharan Africa (excluding high income)
# ..                          ...                                         ...
# 391                         NaN                                         NaN
# 392                         NaN                                         NaN
# 393                         NaN                                         NaN
# 394                         NaN                                         NaN
# 395                         NaN                                         NaN
#
#     group_WB_incomeLevel_exclude_US group_WB_lendingType_exclude_US  \
# 0                       High income                  Not classified
# 1                        Aggregates                      Aggregates
# 2                        Low income                             IDA
# 3                        Aggregates                      Aggregates
# 4               Lower middle income                            IBRD
# ..                              ...                             ...
# 391                             NaN                             NaN
# 392                             NaN                             NaN
# 393                             NaN                             NaN
# 394                             NaN                             NaN
# 395                             NaN                             NaN
#
#        group_is_USA
# 0    Other Entities
# 1    Other Entities
# 2    Other Entities
# 3    Other Entities
# 4    Other Entities
# ..              ...
# 391  Other Entities
# 392  Other Entities
# 393  Other Entities
# 394  Other Entities
# 395  Other Entities
#
# [396 rows x 19 columns]

# %%
# remove not needed variables in this script
del vars, vars_group, k, IndicatorCodes

# %% [markdown]
# ### Final

# %%
# pivot dataset
df = pd.pivot(df, index=["iso_code", "year"], columns="attr", values="value")
df

# reset index
# reset index to make iso_code and year become normal attributes again
df.reset_index(inplace=True)
df

# merge values dataset with groups dataset
df = pd.merge(df_groups, df, on="iso_code", how="right")
df
# Out:
#       iso_code   country group_OWID_Continent              group_UN_Region  \
# 0          ABW     Aruba        North America  Latin America and Caribbean
# 1          ABW     Aruba        North America  Latin America and Caribbean
# 2          ABW     Aruba        North America  Latin America and Caribbean
# 3          ABW     Aruba        North America  Latin America and Caribbean
# 4          ABW     Aruba        North America  Latin America and Caribbean
# ...        ...       ...                  ...                          ...
# 22306      ZWE  Zimbabwe               Africa           Sub-Saharan Africa
# 22307      ZWE  Zimbabwe               Africa           Sub-Saharan Africa
# 22308      ZWE  Zimbabwe               Africa           Sub-Saharan Africa
# 22309      ZWE  Zimbabwe               Africa           Sub-Saharan Africa
# 22310      ZWE  Zimbabwe               Africa           Sub-Saharan Africa
#
#       group_WHO_Region             group_WB_region  \
# 0                  NaN  Latin America & Caribbean
# 1                  NaN  Latin America & Caribbean
# 2                  NaN  Latin America & Caribbean
# 3                  NaN  Latin America & Caribbean
# 4                  NaN  Latin America & Caribbean
# ...                ...                         ...
# 22306           Africa         Sub-Saharan Africa
# 22307           Africa         Sub-Saharan Africa
# 22308           Africa         Sub-Saharan Africa
# 22309           Africa         Sub-Saharan Africa
# 22310           Africa         Sub-Saharan Africa
#
#                              group_WB_adminregion group_WB_incomeLevel  \
# 0                                             NaN          High income
# 1                                             NaN          High income
# 2                                             NaN          High income
# 3                                             NaN          High income
# 4                                             NaN          High income
# ...                                           ...                  ...
# 22306  Sub-Saharan Africa (excluding high income)  Lower middle income
# 22307  Sub-Saharan Africa (excluding high income)  Lower middle income
# 22308  Sub-Saharan Africa (excluding high income)  Lower middle income
# 22309  Sub-Saharan Africa (excluding high income)  Lower middle income
# 22310  Sub-Saharan Africa (excluding high income)  Lower middle income
#
#       group_WB_lendingType  group_WB_longitude  ...  solar_share_elec  \
# 0           Not classified            -70.0167  ...               NaN
# 1           Not classified            -70.0167  ...               NaN
# 2           Not classified            -70.0167  ...               NaN
# 3           Not classified            -70.0167  ...               NaN
# 4           Not classified            -70.0167  ...               NaN
# ...                    ...                 ...  ...               ...
# 22306                Blend             31.0672  ...             0.137
# 22307                Blend             31.0672  ...             0.110
# 22308                Blend             31.0672  ...             0.088
# 22309                Blend             31.0672  ...             0.088
# 22310                Blend             31.0672  ...               NaN
#
#       solar_share_energy wind_cons_change_pct wind_cons_change_twh  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 22306                NaN                  NaN                  NaN
# 22307                NaN                  NaN                  NaN
# 22308                NaN                  NaN                  NaN
# 22309                NaN                  NaN                  NaN
# 22310                NaN                  NaN                  NaN
#
#       wind_consumption wind_elec_per_capita wind_electricity  \
# 0                  NaN                  NaN              NaN
# 1                  NaN                  NaN              NaN
# 2                  NaN                  NaN              NaN
# 3                  NaN                  NaN              NaN
# 4                  NaN                  NaN              NaN
# ...                ...                  ...              ...
# 22306              NaN                  0.0              0.0
# 22307              NaN                  0.0              0.0
# 22308              NaN                  0.0              0.0
# 22309              NaN                  0.0              0.0
# 22310              NaN                  NaN              NaN
#
#       wind_energy_per_capita wind_share_elec  wind_share_energy
# 0                        NaN             NaN                NaN
# 1                        NaN             NaN                NaN
# 2                        NaN             NaN                NaN
# 3                        NaN             NaN                NaN
# 4                        NaN             NaN                NaN
# ...                      ...             ...                ...
# 22306                    NaN             0.0                NaN
# 22307                    NaN             0.0                NaN
# 22308                    NaN             0.0                NaN
# 22309                    NaN             0.0                NaN
# 22310                    NaN             NaN                NaN
#
# [22311 rows x 149 columns]

# %%
# write dataset to json
df.to_json("data.json", orient="records")

# %%
# write dataset to csv
df.to_csv("data.csv", index=False)

# %% [markdown]
# ## Final processing
#
# At this time, we have already finished building our needed dataset, and the dataset can be loaded directly into the web application to render the visualisation.
# This section of the script filters the dataset and transform it into a format that can be loaded into the web easier.

# %%
# Final dataset processing

COUNTRIES_NEEDED_YEARS = [2019]

COUNTRIES_NEEDED_ISO_CODES = [
    "USA",
    "DEU",
    "CAN",
    "FRA",
    "ESP",
    "MEX",
    "ITA",
    "GBR",
    "ARG",
    "BRA",
    "NLD",
    "POL",
    "SWE",
    "BEL",
    "AUS",
    "AUT",
    "THA",
    "OWID_EUR",
    "IND",
    "CHN",
    "PRT",
    "JPN",
    "HUN",
    "ROU",
    "BGR",
    "PAK",
    "ZAF",
    "TUR",
    "CHL",
    "PER",
    "NOR",
    "GRC",
    "DNK",
    "VNM",
    "BGD",
    "EGY",
    "IRL",
    "KOR",
    "ECU",
    "TWN",
    "PHL",
    "TUN",
    "BOL",
    "MNG",
    "BDI",
    "COL",
    "IDN",
    "IRN",
    "MYS",
]

COUNTRIES_NEEDED_VARIABLES = [
    "iso_code",
    "country",
    "year",
    "group_is_USA",
    "group_OWID_Continent",
    "group_WHO_Region",
    "group_WB_incomeLevel",
    "group_WB_lendingType",
    "area",
    "population",
    "gdp",
    "gdp_per_captia",
    "coal_production",
    "electricity_demand",
    "electricity_generation",
    "fossil_fuel_consumption",
    "gas_production",
    "greenhouse_gas_emissions",
    "oil_production",
]

# filter datasets

df_countries = df[
    df["iso_code"].isin(COUNTRIES_NEEDED_ISO_CODES)
    &
    df["year"].isin(COUNTRIES_NEEDED_YEARS)
]

# write dataset to json
df_countries.to_json("final/data.json", orient="records")

# write dataset to csv
df_countries.to_csv("final/data.csv", index=False)

df_countries[COUNTRIES_NEEDED_VARIABLES].to_json("final/countries.json", orient="records")

df_countries[COUNTRIES_NEEDED_VARIABLES].to_csv("final/countries.csv", index=False)

df_countries[COUNTRIES_NEEDED_VARIABLES]
# Out:
#        iso_code         country  year    group_is_USA group_OWID_Continent  \
# 877         ARG       Argentina  2019  Other Entities        South America
# 1185        AUS       Australia  2019  Other Entities              Oceania
# 1307        AUT         Austria  2019  Other Entities               Europe
# 1491        BDI         Burundi  2019  Other Entities               Africa
# 1613        BEL         Belgium  2019  Other Entities               Europe
# 1859        BGD      Bangladesh  2019  Other Entities                 Asia
# 1981        BGR        Bulgaria  2019  Other Entities               Europe
# 2535        BOL         Bolivia  2019  Other Entities        South America
# 2657        BRA          Brazil  2019  Other Entities        South America
# 3209        CAN          Canada  2019  Other Entities        North America
# 3455        CHL           Chile  2019  Other Entities        South America
# 3577        CHN           China  2019  Other Entities                 Asia
# 4228        COL        Colombia  2019  Other Entities        South America
# 4968        DEU         Germany  2019  Other Entities               Europe
# 5214        DNK         Denmark  2019  Other Entities               Europe
# 5830        ECU         Ecuador  2019  Other Entities        South America
# 5952        EGY           Egypt  2019  Other Entities               Africa
# 6238        ESP           Spain  2019  Other Entities               Europe
# 6773        FRA          France  2019  Other Entities               Europe
# 7141        GBR  United Kingdom  2019  Other Entities               Europe
# 7798        GRC          Greece  2019  Other Entities               Europe
# 8718        HUN         Hungary  2019  Other Entities               Europe
# 9088        IDN       Indonesia  2019  Other Entities                 Asia
# 9334        IND           India  2019  Other Entities                 Asia
# 9456        IRL         Ireland  2019  Other Entities               Europe
# 9578        IRN            Iran  2019  Other Entities                 Asia
# 10006       ITA           Italy  2019  Other Entities               Europe
# 10252       JPN           Japan  2019  Other Entities                 Asia
# 10746       KOR     South Korea  2019  Other Entities                 Asia
# 12782       MEX          Mexico  2019  Other Entities        North America
# 13460       MNG        Mongolia  2019  Other Entities                 Asia
# 14034       MYS        Malaysia  2019  Other Entities                 Asia
# 14688       NLD     Netherlands  2019  Other Entities               Europe
# 14810       NOR          Norway  2019  Other Entities               Europe
# 15662  OWID_EUR          Europe  2019  Other Entities                  NaN
# 15907       PAK        Pakistan  2019  Other Entities                 Asia
# 16091       PER            Peru  2019  Other Entities        South America
# 16213       PHL     Philippines  2019  Other Entities                 Asia
# 16459       POL          Poland  2019  Other Entities               Europe
# 16827       PRT        Portugal  2019  Other Entities               Europe
# 17421       ROU         Romania  2019  Other Entities               Europe
# 18986       SWE          Sweden  2019  Other Entities               Europe
# 19726       THA        Thailand  2019  Other Entities                 Asia
# 20406       TUN         Tunisia  2019  Other Entities               Africa
# 20528       TUR          Turkey  2019  Other Entities                 Asia
# 20712       TWN          Taiwan  2019  Other Entities                 Asia
# 21264       USA   United States  2019   United States        North America
# 21756       VNM         Vietnam  2019  Other Entities                 Asia
# 22064       ZAF    South Africa  2019  Other Entities               Africa
#
#             group_WHO_Region group_WB_incomeLevel group_WB_lendingType  \
# 877                 Americas  Upper middle income                 IBRD
# 1185         Western Pacific          High income       Not classified
# 1307                  Europe          High income       Not classified
# 1491                  Africa           Low income                  IDA
# 1613                  Europe          High income       Not classified
# 1859         South-East Asia  Lower middle income                  IDA
# 1981                  Europe  Upper middle income                 IBRD
# 2535                Americas  Lower middle income                 IBRD
# 2657                Americas  Upper middle income                 IBRD
# 3209                Americas          High income       Not classified
# 3455                Americas          High income                 IBRD
# 3577         Western Pacific  Upper middle income                 IBRD
# 4228                Americas  Upper middle income                 IBRD
# 4968                  Europe          High income       Not classified
# 5214                  Europe          High income       Not classified
# 5830                Americas  Upper middle income                 IBRD
# 5952   Eastern Mediterranean  Lower middle income                 IBRD
# 6238                  Europe          High income       Not classified
# 6773                  Europe          High income       Not classified
# 7141                  Europe          High income       Not classified
# 7798                  Europe          High income       Not classified
# 8718                  Europe          High income       Not classified
# 9088         South-East Asia  Lower middle income                 IBRD
# 9334         South-East Asia  Lower middle income                 IBRD
# 9456                  Europe          High income       Not classified
# 9578   Eastern Mediterranean  Lower middle income                 IBRD
# 10006                 Europe          High income       Not classified
# 10252        Western Pacific          High income       Not classified
# 10746        Western Pacific          High income       Not classified
# 12782               Americas  Upper middle income                 IBRD
# 13460        Western Pacific  Lower middle income                 IBRD
# 14034        Western Pacific  Upper middle income                 IBRD
# 14688                 Europe          High income       Not classified
# 14810                 Europe          High income       Not classified
# 15662                    NaN                  NaN                  NaN
# 15907  Eastern Mediterranean  Lower middle income                Blend
# 16091               Americas  Upper middle income                 IBRD
# 16213        Western Pacific  Lower middle income                 IBRD
# 16459                 Europe          High income                 IBRD
# 16827                 Europe          High income       Not classified
# 17421                 Europe  Upper middle income                 IBRD
# 18986                 Europe          High income       Not classified
# 19726        South-East Asia  Upper middle income                 IBRD
# 20406  Eastern Mediterranean  Lower middle income                 IBRD
# 20528                 Europe  Upper middle income                 IBRD
# 20712                    NaN          High income       Not classified
# 21264               Americas          High income       Not classified
# 21756        Western Pacific  Lower middle income                 IBRD
# 22064                 Africa  Upper middle income                 IBRD
#
#               area    population           gdp  gdp_per_captia  \
# 877    2736690.000  4.493871e+07  4.519324e+11    10056.637940
# 1185   7692020.000  2.536574e+07  1.391953e+12    54875.285956
# 1307     82520.000  8.879920e+06  4.450119e+11    50114.401110
# 1491     25680.000  1.153058e+07  2.631434e+09      228.213589
# 1613     30280.000  1.148898e+07  5.352887e+11    46591.491607
# 1859    130170.000  1.630462e+08  3.025713e+11     1855.740094
# 1981    108560.000  6.975761e+06  6.891542e+10     9879.268533
# 2535   1083300.000  1.151310e+07  4.089532e+10     3552.068143
# 2657   8358140.000  2.110495e+08  1.877824e+12     8897.552966
# 3209   8965590.000  3.760123e+07  1.742015e+12    46328.671841
# 3455    743532.000  1.895204e+07  2.793855e+11    14741.714404
# 3577   9424702.900  1.407745e+09  1.427994e+13    10143.838172
# 4228   1109500.000  5.033944e+07  3.234299e+11     6424.979492
# 4968    349380.000  8.309296e+07  3.888327e+12    46794.899292
# 5214     40000.000  5.814422e+06  3.475613e+11    59775.735096
# 5830    248360.000  1.737366e+07  1.081080e+11     6222.524653
# 5952    995450.000  1.003881e+08  3.030809e+11     3019.092283
# 6238    499603.479  4.713484e+07  1.393046e+12    29554.490517
# 6773    547557.000  6.724893e+07  2.728870e+12    40578.644285
# 7141    241930.000  6.683633e+07  2.878674e+12    43070.498360
# 7798    128900.000  1.072158e+07  2.051442e+11    19133.757764
# 8718     91260.000  9.771141e+06  1.635265e+11    16735.659779
# 9088   1877519.000  2.706256e+08  1.119091e+12     4135.201531
# 9334   2973190.000  1.366418e+09  2.870504e+12     2100.751461
# 9456     68890.000  4.934340e+06  3.991221e+11    80886.615739
# 9578   1628760.000  8.291389e+07  2.582455e+11     3114.622753
# 10006   297730.000  5.972908e+07  2.009384e+12    33641.633751
# 10252   364500.000  1.262649e+08  5.148782e+12    40777.608697
# 10746    97520.000  5.176482e+07  1.651423e+12    31902.416905
# 12782  1943950.000  1.275755e+08  1.269434e+12     9950.450080
# 13460  1557255.000  3.225166e+06  1.420636e+10     4404.845830
# 14034   328550.000  3.194979e+07  3.652763e+11    11432.822997
# 14688    33670.000  1.734487e+07  9.101943e+11    52476.273253
# 14810   365107.850  5.347896e+06  4.049414e+11    75719.752897
# 15662          NaN  7.483814e+08           NaN             NaN
# 15907   770880.000  2.165653e+08  2.790566e+11     1288.556325
# 16091  1280000.000  3.251046e+07  2.284709e+11     7027.612207
# 16213   298170.000  1.081166e+08  3.768233e+11     3485.340844
# 16459   306170.000  3.796548e+07  5.972806e+11    15732.203131
# 16827    91605.600  1.028626e+07  2.399869e+11    23330.817289
# 17421   230080.000  1.937165e+07  2.498816e+11    12899.346111
# 18986   407310.000  1.027889e+07  5.338795e+11    51939.429745
# 19726   510890.000  6.962558e+07  5.442638e+11     7817.009671
# 20406   155360.000  1.169472e+07  4.180458e+10     3574.654024
# 20528   769630.000  8.342961e+07  7.610044e+11     9121.515167
# 20712          NaN  2.377388e+07           NaN             NaN
# 21264  9147420.000  3.283300e+08  2.143322e+13    65279.529026
# 21756   310070.000  9.646211e+07  2.619212e+11     2715.275980
# 22064  1213090.000  5.855827e+07  3.879346e+11     6624.761865
#
#        coal_production  electricity_demand  electricity_generation  \
# 877                NaN              143.15                  132.46
# 1185          3669.878              250.26                  250.26
# 1307               NaN               73.99                   70.86
# 1491               NaN                0.46                    0.36
# 1613               NaN               90.45                   92.30
# 1859               NaN               86.39                   79.60
# 1981            56.722               38.01                   43.82
# 2535               NaN                9.99                    9.99
# 2657            25.144              639.51                  614.55
# 3209           316.326              586.70                  633.71
# 3455               NaN               80.17                   80.17
# 3577         22154.439             7439.41                 7456.21
# 4228           673.811               75.58                   75.27
# 4968           330.528              566.82                  599.49
# 5214               NaN               35.33                   29.52
# 5830               NaN               29.87                   31.69
# 5952               NaN              182.70                  182.99
# 6238            18.377              277.75                  270.89
# 6773               NaN              508.02                  565.69
# 7141            17.540              342.82                  321.65
# 7798            59.633               58.50                   48.56
# 8718            11.554               46.77                   34.19
# 9088          4222.599              280.50                  278.82
# 9334          3499.012             1599.78                 1603.48
# 9456               NaN               31.36                   30.72
# 9578               NaN              314.13                  317.76
# 10006              NaN              329.49                  291.35
# 10252            4.893              987.50                  987.50
# 10746            5.963              560.12                  560.12
# 12782           64.017              330.40                  329.58
# 13460          302.306                8.23                    6.53
# 14034              NaN              162.18                  162.83
# 14688              NaN              121.66                  120.80
# 14810              NaN              134.12                  134.08
# 15662         1799.794             4747.58                 4753.02
# 15907           35.393              120.89                  120.40
# 16091              NaN               55.53                   55.47
# 16213              NaN              100.91                  100.91
# 16459          518.821              173.66                  163.04
# 16827              NaN               55.13                   51.73
# 17421           45.682               60.70                   59.18
# 18986              NaN              142.26                  168.42
# 19726           41.072              203.85                  181.19
# 20406              NaN               20.39                   20.55
# 20528          201.773              302.21                  302.79
# 20712              NaN              269.68                  269.68
# 21264         3969.054             4195.02                 4155.98
# 21756          302.106              215.33                  214.08
# 22064         1726.006              226.76                  233.42
#
#        fossil_fuel_consumption  gas_production  greenhouse_gas_emissions  \
# 877                    792.530         416.158                     46.54
# 1185                  1493.910        1431.490                    147.18
# 1307                   275.456             NaN                     11.37
# 1491                       NaN             NaN                      0.09
# 1613                   579.424             NaN                     17.19
# 1859                   452.465         252.844                     42.68
# 1981                   145.296             NaN                     16.20
# 2535                       NaN         149.503                      3.15
# 2657                  1873.529         257.465                     76.58
# 3209                  2682.728        1689.858                     84.62
# 3455                   363.470             NaN                     32.45
# 3577                 33562.691        1775.598                   4174.07
# 4228                   379.969         131.939                     13.44
# 4968                  2805.828          53.308                    216.76
# 5214                   127.582          32.026                      6.06
# 5830                   143.671             NaN                      4.65
# 5952                  1024.059         649.387                     86.88
# 6238                  1151.993             NaN                     65.96
# 6773                  1384.396             NaN                     38.77
# 7141                  1689.786         395.352                     85.61
# 7798                   289.293             NaN                     21.63
# 8718                   217.870             NaN                      8.69
# 9088                  2266.607         675.834                    184.74
# 9334                  8532.921         269.060                   1022.08
# 9456                   152.871             NaN                     10.30
# 9578                  3236.013        2414.215                    155.86
# 10006                 1494.494          46.212                    102.57
# 10252                 4477.606             NaN                    473.70
# 10746                 2950.233             NaN                    272.42
# 12782                 1929.125         312.949                    140.86
# 13460                      NaN             NaN                      4.83
# 14034                 1155.180         792.647                     89.81
# 14688                  901.096         278.444                     54.91
# 14810                  163.693        1142.598                      4.63
# 15662                17036.962        2352.054                   1386.27
# 15907                  850.364         326.862                     43.13
# 16091                  239.752         134.958                     13.22
# 16213                  499.041             NaN                     58.20
# 16459                 1101.944          39.852                    109.39
# 16827                  215.383             NaN                     15.26
# 17421                  288.943          96.226                     16.84
# 18986                  197.403             NaN                      7.92
# 19726                 1436.945         357.727                     89.70
# 20406                      NaN             NaN                      9.69
# 20528                 1478.433             NaN                    124.64
# 20712                 1247.893             NaN                    154.73
# 21264                21957.297        9299.875                   1633.22
# 21756                  979.427          98.526                    115.51
# 22064                 1380.084             NaN                    170.72
#
#        oil_production
# 877           335.349
# 1185          224.077
# 1307              NaN
# 1491              NaN
# 1613              NaN
# 1859              NaN
# 1981              NaN
# 2535              NaN
# 2657         1753.507
# 3209         3064.065
# 3455              NaN
# 3577         2221.493
# 4228          542.612
# 4968              NaN
# 5214           58.350
# 5830          330.996
# 5952          369.974
# 6238              NaN
# 6773              NaN
# 7141          602.640
# 7798              NaN
# 8718              NaN
# 9088          444.020
# 9334          437.491
# 9456              NaN
# 9578         1834.805
# 10006          49.760
# 10252             NaN
# 10746             NaN
# 12782        1103.901
# 13460             NaN
# 14034         351.386
# 14688             NaN
# 14810         913.482
# 15662        1840.145
# 15907             NaN
# 16091          71.005
# 16213             NaN
# 16459             NaN
# 16827             NaN
# 17421          41.484
# 18986             NaN
# 19726         195.430
# 20406          22.966
# 20528             NaN
# 20712             NaN
# 21264        8697.417
# 21756         133.073
# 22064             NaN
